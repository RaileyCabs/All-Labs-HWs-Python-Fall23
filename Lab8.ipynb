# %% [markdown]
# # Lab 8 - File I/O and Frankenstein
# ### Name: James Railey Cabrera
# This lab is designed to give you practice with file I/O and to give you a chance to work with a larger program.  You will be writing a program that will read in a text file and then create a new file that is a modified version of the original.  The program will then read in the modified file and print out some statistics about the file.

# %%
# Take in the Frankenstein text using open and read
# Open the file

with open('frankenstein.txt', 'r', encoding='utf-8' ) as file:
    text = file.read()

# %%
# Show the start of the file (first 1000 characters)
# Note: Use slicing to get the first 1000 characters
test = text[:1000]
print(test)
# Out:
# The Project Gutenberg eBook of Frankenstein; Or, The Modern Prometheus
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Frankenstein; Or, The Modern Prometheus
#
#
# Author: Mary Wollstonecraft Shelley
#
# Release date: October 1, 1993 [eBook #84]
#                 Most recently updated: December 2, 2022
#
# Language: English
#
# Credits: Judith Boss, Christy Phillips, Lynn Hanninen and David Meltzer. HTML version by Al Haines.
#         Further corrections by Menno de Leeuw.
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***
#
#
#
# Frankenstein;
#
# or, the Modern Prometheu

# %%
# Show the end of the file (last 1000 characters)
# Note: Use slicing to get the last 1000 characters
#  H  E  L  L  O
#  0  1  2  3  4
# -5 -4 -3 -2 -1
tail = text[-1000:]
print(tail)
# Out:
# visit: www.gutenberg.org/donate.
#
# Section 5. General Information About Project Gutenberg™ electronic works
#
# Professor Michael S. Hart was the originator of the Project
# Gutenberg™ concept of a library of electronic works that could be
# freely shared with anyone. For forty years, he produced and
# distributed Project Gutenberg™ eBooks with only a loose network of
# volunteer support.
#
# Project Gutenberg™ eBooks are often created from several printed
# editions, all of which are confirmed as not protected by copyright in
# the U.S. unless a copyright notice is included. Thus, we do not
# necessarily keep eBooks in compliance with any particular paper
# edition.
#
# Most people start at our website which has the main PG search
# facility: www.gutenberg.org.
#
# This website includes information about Project Gutenberg™,
# including how to make donations to the Project Gutenberg Literary
# Archive Foundation, how to help produce our new eBooks, and how to
# subscribe to our email newsletter to hear about new eBooks.

# %%
# Notice there is a lot of extra stuff at the beginning and end of the file (The header and footer)
# Lets remove the header and footer
# Create a method called remove_gutenberg_header_footer that takes in a string and returns a string
# The method should remove the header and footer from the string
# The method should return the string with the header and footer removed
# Note: The header and footer are the same for all Gutenberg texts
# Note: The header and footer are marked by the following strings:
# *** START OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***
# *** END OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***


def remove_gutenberg_header_footer(text):
    start = text.find('*** START OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***')
    end = text.find('*** END OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***')
    return text[start:end]


# Call the remove_gutenberg_header_footer method with the text and save the result to a variable called text
fixed_text = remove_gutenberg_header_footer(text)

# %%
# Data Analysis
# Now that we have the text, lets do some analysis
# How many chapters are in the text?
# Note: Each chapter starts with the text "Chapter" and then a number
# Note: Use the count method to count the number of chapters but only in the first 1000 characters of the text
# Note: There are 24 chapters 
# Note: Use slicing to get the first 1000 characters
print(fixed_text[:1000].count('Chapter'))


# Try to remove punctuation
# Note: Use the replace method to replace punctuation with nothing
# Note: Use the lower method to make the text lowercase
# Note: Use the split method to split the text into words
# remember methods can be chained together like this: text.replace().replace().replace().lower().split()
words_cleaned = fixed_text.replace('.', '').replace(',', '').replace(';', '').replace('?', '').replace('!', '').replace(':', '').replace('(', '').replace(')', '').replace('"', '').lower().split()

# How many unique words are in the text?
# A unique word is a word that only appears once in the text
# Note: Use the set method to get the unique words
# Note: Use the len method to get the number of unique words
words = fixed_text.split()
unique_words = set(words)
print(len(unique_words)) 
print(unique_words)

unique_words_cleaned = set(words_cleaned)
print("Cleaned Words Length: ",len(unique_words_cleaned))
print(unique_words_cleaned)
# How many times does the word "monster" appear in the text?
# Note: Use the count method to count the number of times "monster" appears in the text
unique_words_list = list(unique_words_cleaned)
words_cleaned.count('')
# Out:
# 24
# 11608
# {'murderer?', 'plunge', 'senseless', 'phrase', '“I', 'Clerval:', 'confinement.', 'himself.', 'exchange', 'sex,', 'places.', 'pronunciation', 'anyone', 'decreased;', 'watery,', 'prudent.', 'cloudless.', 'hills', 'parts', 'Ingolstadt;', 'tone', 'distant,', 'canst', 'stores', 'sinking', 'dangerous,', 'sty', 'clever', 'Uri,', 'drawing', 'begin', 'halo', 'knew.', 'affection.', 'fever', 'madman,', 'alas,', 'glacier,', 'gardens,', 'elements,', 'positively', 'chanced', 'here', 'uncommonly', 'transported', 'occasion.', 'deeply.', 'void', 'repeated', 'dogs.', 'Ireland', 'employments', 'die', 'country?”', 'increased,', 'England', 'acquit', 'fulfil', '5', 'alchemists', 'continually,', 'strangers.', 'circumstance,', 'lightning', 'trained', 'infliction.', 'minutes,', 'kept', 'touched.', 'Among', 'stayed', 'yours;', 'Mary', 'sir,”', 'rest', 'labour—the', 'setting', 'grateful;', 'representations,', 'ragged', 'fulfilled!”', 'common', 'wherever', 'drunken', 'professors', 'expiration', 'purpose', 'Happy,', 'Pacific', 'fail.', 'insurrection', 'disgust', 'imperatively', 'poison', 'sallies', 'alighted', 'sad.', 'tones', 'wounded', 'accurate', 'repay', 'heaven!”', 'hills,', 'twinkling', 'minutiae', 'months.', 'existence,', 'subscribed', 'expected', 'treble', 'print', 'formation,', 'outlines.', 'condemned.', 'strongly.', 'wherefore', 'overpowering', 'angel’s', 'August', '15', 'misfortune.”', 'vile', 'mould,', 'mechanical', 'assassin', 'was;', 'impatience', 'flower', 'qualities', 'inflicted', 'Mine', 'exile,', 'pains', 'voices,', 'story', 'violence,', 'continued', 'adventurous', 'dirge!”', 'eyes)', 'thousands,', 'work,', 'offspring.', '“circumstances', 'nuts', 'simple,', 'death.”', 'carrying', 'hour’s', 'market-woman', 'influenced', 'desolate', 'truth', 'pleasant', 'elementary', 'Believe', 'girl', 'prejudices', 'spectators', 'wrung', 'proved', 'criminality', 'meanwhile', 'texture', 'change,', 'steeple', 'forget.', 'London', 'sorry.', 'also,', 'entreat', 'thyself;', 'calm', 'anxious', 'model', 'promise?', 'life—the', 'deemed', 'comprehend.', 'infamy', 'grace,', 'suppliant,', 'yet,', 'Still,', 'expected;', 'Safie', 'than,', 'machinations', 'ravine,', 'magnitude', 'resource,', 'incipient', 'residence,', 'wished,', 'chimney', 'Sweet', 'upon.', 'Under', 'passed,', 'pursuing', 'disguise.', 'England.', 'glaring', 'tastes,', 'year', 'impossible', 'watchful,', 'Below', 'forget:', 'occupations.', 'precipitation.', 'quivered', 'over', 'How', 'songs', 'cousins.', 'deserve.', 'son’s', 'thing;', 'former,', 'him', 'ice-rock', 'pictures', 'Clerval—and', 'created.', 'enemy;', 'endured.', 'make', 'crawling', 'grovel', 'transport', 'regulate', 'voiceless', 'miraculous', 'suddenly', 'story.', 'glut', 'extensive', 'caused', 'quick,', '19', 'anatomy,', 'even', 'fit.', 'Walton!', 'activity', 'rumbling', 'Felix;', 'proportion,', 'nurse,', 'indulge', 'eluded', 'followed,', 'evaded', 'Enter', 'amuse', 'ecstasy', 'get', 'contemplated.', 'refuse.', 'absence,', 'stones', 'But', 'demands.', 'far,', 'wears', 'procure,', 'exordium,', 'destroyed;', 'accidents', 'chasms', 'mutability!', 'money', 'included', 'Man!', 'system', 'plain.', 'abortive', 'unfitted', 'Again', 'curiosity.', 'deformity.', 'names', 'accept', 'brightness', 'moonshine,', 'inhabitants;', 'relative', 'attach', 'agree', 'cell', 'illuminate', 'organization;', 'deference', 'shape.', 'whenever', 'glorious', 'solicitude', 'sole', 'yourself;', 'insect!', 'wasting', 'Turk,', 'grades', 'incredulous,', 'return,', 'divine;', 'pleasure', 'Everybody', 'worship', 'wreck,', 'irretrievable,', 'rankle', 'step.', 'immutable', 'carriage', 'myriads', 'fitting', 'lessened,', 'elapsed', 'imprudence', 'hate,', 'express', 'executed', 'pleasure;', 'lovedst.', 'shores.', 'exclaim.', 'resolutions.', 'something,', 'health', 'weary', 'forebodings.', 'transitory', 'enormity', 'talk', 'degree,', 'division', 'him—that', 'unbounded', 'dimmed', 'death', 'Walton', 'trampled', 'Secheron,', 'ceremony;', 'crowd', 'dominions.', 'guarded', 'noise,', 'imag ...
# Cleaned Words Length:  7649
# {'plunge', 'senseless', 'february', 'phrase', 'exchange', 'pronunciation', 'anyone', 'unequal', 'hills', 'parts', 'tone', 'canst', 'stores', 'sinking', 'sty', 'clever', 'drawing', 'begin', 'halo', 'fever', 'dominions', 'positively', 'chanced', 'here', 'uncommonly', 'transported', 'void', 'repeated', 'employments', 'die', 'vaud', 'seashore', 'acquit', 'fulfil', '5', 'homer', 'alchemists', 'self-accusations—poor', 'posterity”', 'lightning', 'trained', 'kept', 'stayed', 'rest', 'labour—the', 'setting', 'justine”', 'contumely', 'ragged', 'common', 'wherever', 'drunken', 'professors', 'elizabeth', 'pays_', 'expiration', 'victim”', 'purpose', 'trance', 'unhappiness”', 'fog', 'insurrection', 'disgust', 'imperatively', 'poison', 'sallies', 'alighted', 'him’', 'tones', 'wounded', 'guile', 'accurate', 'repay', 'twinkling', 'minutiae', 'subscribed', 'm', 'expected', 'treble', 'print', 'wherefore', 'overpowering', 'mortification', 'angel’s', 'victim’', '15', 'vile', 'mechanical', 'assassin', 'mountain-top', 'impatience', 'flower', 'qualities', 'inflicted', 'self-control', 'pains', 'child’', 'doth', 'story', 'continued', 'adventurous', '“circumstances', 'nuts', 'carrying', 'hour’s', 'market-woman', 'desolate', 'influenced', 'truth', 'pleasant', 'elementary', 'wrung', 'girl', 'prejudices', 'spectators', 'proved', 'criminality', 'meanwhile', 'texture', 'steeple', 'here”', 'lived”', 'entreat', 'calm', 'anxious', 'model', 'class', 'life—the', 'deemed', 'infamy', 'orkney', 'downstairs', 'machinations', 'magnitude', 'incipient', 'chimney', 'race”', 'chinks', 'seclusion', 'lost_', 'pursuing', 'glaring', 'year', 'impossible', 'refrained', 'mechanics', '_wood_', 'quivered', 'over', 'songs', 'missed', 'son’s', 'him', 'ice-rock', 'pictures', 'make', 'crawling', 'grovel', 'transport', 'regulate', 'voiceless', 'miraculous', 'suddenly', 'glut', 'extensive', 'caused', '“can', '19', 'even', 'empires_', 'activity', 'rumbling', 'indulge', 'eluded', 'evaded', 'hands”', 'amuse', 'ecstasy', 'get', 'stones', 'wears', 'accidents', 'africa', 'chasms', 'money', 'included', 'system', 'abortive', 'unfitted', 'names', 'accept', 'brightness', 'relative', 'attach', 'agree', 'cell', 'illuminate', 'hurricane', 'deference', 'whenever', 'glorious', 'solicitude', 'sole', 'hot', 'roncesvalles', 'wasting', 'grades', 'threatening', 'pleasure', 'worship', 'rankle', 'immutable', 'carriage', 'myriads', 'fitting', 'elapsed', 'star-light', 'imprudence', 'express', 'executed', 'health', 'weary', 'frenchwoman', 'transitory', 'enormity', 'talk', 'excluded', 'festering', 'division', 'him—that', 'unbounded', 'tay', 'dimmed', 'death', 'england', 'trampled', 'crowd', 'artery', 'guarded', 'attained', 'clock', '“one', 'acquired', 'snow”', 'uneducated', 'intrusion', 'lavenza', 'hideousness', 'mountain-stream', '“are', 'best', 'interpret', 'objects', 'terms', 'you”', 'clear', 'awaken', 'travel', 'september', 'cruelly', 'groaned', 'induce', 'hurried', 'degree', 'development', 'affluence', 'maintained', 'florins', 'unquiet', 'howl', 'disposed', 'mental', 'offered', 'floundering', 'brother-in-law', 'converse', 'avenge', 'mistaken”', 'termination', 'dearer', 'conditions', 'dismissing', 'attack', 'are', 'croaking', 'physiognomy', 'my', 'speck', 'contortions', 'assist', 'greek', 'resignation', 'dare', 'circulates', 'reconciled', 'melancholy', 'blasted', 'braces', 'dæmon', 'son”', 'spent', 'filled', 'overwhelm', 'conquer', 'senses', 'heal', 'ear', 'population', 'archangel', 'entire', 'trials', 'infused', 'repentance”', 'diverted', 'discoverers', 'conversation', 'inclinations', 'werter’s', 'those', 'disturbs', 'grudge', 'severe', 'charmed', 'gutenberg', 'consequence', 'irretrievable', 'plaited', 'including', 'agonised', 'winter', 'voluntarily', 'undeceive', 'wonders', 'piece', 'havre-de-grace', 'charms', 'flashes', 'filial', 'venting', 'moonshine', 'alleviate', 'restrain', 'alternate', 'visitor', 'mildly', 'turn', 'creator”', 'go’', 'revolution', 'possession', 'stepped', 'peru', 'light', 'conceiving' ...
# 0

# %%
## Get top 10 words in the text
# Note: Use the Counter method to get the top 10 words
# Note: Use the most_common method to get the top 10 words

# You will need to import Counter from collections to use the Counter method
# from collections import Counter 
# You might need to install collections using pip (in the terminal type: pip install collections)
from collections import Counter

# Print the top 10 words in the text
words = Counter(words_cleaned)
words.most_common(10)
# Out:
# [('the', 4155),
#  ('and', 2958),
#  ('i', 2765),
#  ('of', 2639),
#  ('to', 2082),
#  ('my', 1751),
#  ('a', 1382),
#  ('in', 1122),
#  ('was', 1020),
#  ('that', 1004)]

# %%
#### Extra Credit ####
# Show me something interesting about the text that you found using python it can be anything

from collections import Counter
words = Counter(words_cleaned)
least_common = words.most_common()[:-10-1:-1]

for word, count in least_common:
    print(word, count)

# I learned the words conflagration, exult and rankle today
# Out:
# cabin-window 1
# farewell” 1
# thinks 1
# fade 1
# conflagration 1
# torturing 1
# exult 1
# triumphantly 1
# soon” 1
# rankle 1
